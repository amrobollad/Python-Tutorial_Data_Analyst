# %% [markdown]
# # HTML and Inspecting a Web Page

# %% [markdown]
# ![Screenshot 2024-08-28 131316.jpg](attachment:7bf6c964-7cfe-47cf-9bfa-816965db85d7.jpg)
# https://www.scrapethissite.com/pages/forms/
